# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset//CS_dpt.csv')
df.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
df['Best of Quizzes']>7
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
#       ...
# 44    False
# 45     True
# 46     True
# 47     True
# Name: Best of Quizzes, Length: 48, dtype: bool

# %%
#csvData['Student Name'] = [i if i in csvData['Best of Quizzes']>7 for i in zip(csvData['Student Name'],csvData['Best of Quizzes'])]

# %%
df[df['Best of Quizzes']>7]
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 5   022-14-110232  BS(CS)        Ameer Hamza   25     9.0     6.0
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26     9.0     6.0
# 8   022-14-110601  BS(CS)     Areesha Sohail   19     9.0     4.0
# ..            ...     ...                ...  ...     ...     ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 5                 9           8.0          10.0                   10
# 7                 9           8.0          10.0                   10
# ...

# %%
df[df['Best of Quizzes']>7].count()
# Out:
# Student Code            23
# Degree                  23
# Student Name            23
# Mid                     23
#                         ..
# Total Sessional (50)    23
# Final (50)              23
# Total (100)             23
# Grade                   23
# Length: 14, dtype: int64

# %%
df[(df['Best of Quizzes']>7) & (df['Best of Assignments']>7)]
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 5   022-14-110232  BS(CS)        Ameer Hamza   25     9.0     6.0
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26     9.0     6.0
# 8   022-14-110601  BS(CS)     Areesha Sohail   19     9.0     4.0
# ..            ...     ...                ...  ...     ...     ...
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 5                 9           8.0          10.0                   10
# 7                 9           8.0          10.0                   10
# ...

# %%
df[(df['Best of Quizzes']>7) & (df['Best of Assignments']>7)].count()
# Out:
# Student Code            21
# Degree                  21
# Student Name            21
# Mid                     21
#                         ..
# Total Sessional (50)    21
# Final (50)              21
# Total (100)             21
# Grade                   21
# Length: 14, dtype: int64

# %%
df["Degree"].count()
# Out:
# 48

# %%
df[(df["Quiz 1"]>9) | (df["Quiz 1"]>8)].count()
# Out:
# Student Code            13
# Degree                  13
# Student Name            13
# Mid                     13
#                         ..
# Total Sessional (50)    13
# Final (50)              13
# Total (100)             13
# Grade                   13
# Length: 14, dtype: int64

# %%
df["Remarks"] = ["Excellent" if i=="A" else "B-GRADE" if i=="B" else "C-Grade" if i=="C" else "Fail" for i in df.Grade]

# %%
df.head(8)
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0     6.0
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0     6.0
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0     6.0
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# ...

# %%
df.isna()
# Out:
#     Student Code  Degree  Student Name    Mid  Quiz 1  Quiz 2  \
# 0          False   False         False  False   False   False
# 1          False   False         False  False    True   False
# 2          False   False         False  False   False   False
# 3          False   False         False  False   False   False
# ..           ...     ...           ...    ...     ...     ...
# 44         False   False         False  False   False   False
# 45         False   False         False  False   False   False
# 46         False   False         False  False   False   False
# 47         False   False         False  False   False   False
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0             False         False         False                False
# 1             False         False         False                False
# 2             False         False         False                False
# ...

# %%
df.ffill()
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     8.0     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# ..            ...     ...                ...  ...     ...     ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 1                 5           8.0          10.0                   10
# 2                 5           8.0          10.0                   10
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.head(37)
# Out:
#      Student Code  Degree          Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)           Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)           Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585  BS(CS)          Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)        Ahmed Ali Raza   14     7.0     2.0
# ..            ...     ...                   ...  ...     ...     ...
# 33   022-14-19919  BS(CS)  Muhammad Younus Baig   20     4.0     2.0
# 34  022-14-110413  BS(CS)      Nazeer Bin Zafar   25     9.0     6.0
# 35   022-14-19923  BS(CS)            Rabi Ahmed   20     8.0     5.0
# 36  022-14-110582  BS(CS)            Rida Nasim   25     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 1                 5           8.0          10.0                   10
# ...

# %%
df
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# ..            ...     ...                ...  ...     ...     ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 1                 5           8.0          10.0                   10
# 2                 5           8.0          10.0                   10
# ...

# %% [markdown]
# # Class SUNDAY 26/10

# %%
df.sort_values(by="Best of Quizzes")
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     0.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     0.0
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# ..            ...     ...                             ...  ...     ...
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 15     0.0                0           0.0           0.0                    0
# 32     2.0                2           8.0          10.0                   10
# ...

# %%
df.sort_values(by="Student Name")
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# ..            ...     ...                ...  ...     ...     ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 1                 5           8.0          10.0                   10
# 2                 5           8.0          10.0                   10
# ...

# %%
df.sort_values(by=["Best of Quizzes","Student Name"]) #pehle yeh best fo quizzes se sort kre ga phr agr 3 4 logon k marks same hain tou ab wo student name se sort krdega
# Out:
#      Student Code  Degree           Student Name  Mid  Quiz 1  Quiz 2  \
# 15   022-14-19916  BS(CS)           Haseeb Sajid   18     0.0     0.0
# 32  022-14-110035  BS(CS)  Muhammad Wajahat Khan    9     0.0     2.0
# 33   022-14-19919  BS(CS)   Muhammad Younus Baig   20     4.0     2.0
# 39  022-14-110107  BS(CS)            Sania Iqbal   28     4.0     4.0
# ..            ...     ...                    ...  ...     ...     ...
# 40  022-14-110584  BS(CS)            Sharif Taqi   27     9.0     6.0
# 43  022-14-110451  BS(CS)      Syed Faizan Uddin   28     9.0     4.0
# 45  022-14-110400  BS(CS)      Syeda Sabika Raza   27     9.0     6.0
# 47  022-14-110219  BS(CS)            Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 15                0           0.0           0.0                    0
# 32                2           8.0          10.0                   10
# ...

# %%
df.sort_values(['Best of Quizzes','Assignment 1'],ascending=False)
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
# ..            ...     ...                             ...  ...     ...
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     0.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     0.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 21     6.0                9           9.0          11.0                   11
# 36     5.0                9           9.0           0.0                    9
# ...

# %%
pd.options.display.max_rows = 10

# %%
df
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# 4   022-14-110648  BS(CS)    Ahsan Ali Vohra   27     7.0     6.0
# ..            ...     ...                ...  ...     ...     ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# ...

# %%
pd.options.display.max_rows = 9

# %%
df
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# ..            ...     ...                ...  ...     ...     ...
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# 1                 5           8.0          10.0                   10
# 2                 5           8.0          10.0                   10
# ...

# %%
obj = pd.Series([-5,0,2,4,4,7,7],index=[1,5,4,3,6,0,2])
obj
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# dtype: int64

# %%
obj.sort_values(inplace=True)
obj
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# dtype: int64

# %%
obj.rank(method='first')
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.0
# 6    5.0
# 0    6.0
# 2    7.0
# dtype: float64

# %%
obj.rank()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.5
# 6    4.5
# 0    6.5
# 2    6.5
# dtype: float64

# %%
arr = np.array([3,5,6,7,2,9])

# %%
print(arr.max())
print(np.max(arr))
print(arr.argmax()) #argmax is giving index of max value
# Out:
# 9
# 9
# 5

# %%
df1 = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],[np.nan, np.nan], [0.75, -1.3]],index=['a', 'b', 'c', 'd'],columns=['one', 'two'])

# %%
df1
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df1.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df["Mid"].max()
# Out:
# 30

# %%
df["Mid"].idxmax()
# Out:
# 10

# %% [markdown]
# # Correlation and Covariance

# %%
import pandas_datareader.data as web

# %%
all_data = {ticker: web.get_data_yahoo(ticker)
 for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}

# %%
all_data
# Out:
# {'AAPL':                   High         Low        Open       Close      Volume  \
#  Date
#  2014-10-28  106.739998  105.349998  105.400002  106.739998  48060900.0
#  2014-10-29  107.370003  106.360001  106.650002  107.339996  52687900.0
#  2014-10-30  107.349998  105.900002  106.959999  106.980003  40654800.0
#  2014-10-31  108.040001  107.209999  108.010002  108.000000  44639300.0
#  ...                ...         ...         ...         ...         ...
#  2019-10-22  242.199997  239.619995  241.160004  239.960007  20573400.0
#  2019-10-23  243.240005  241.220001  242.100006  243.179993  18957200.0
#  2019-10-24  244.800003  241.809998  244.509995  243.580002  17318800.0
#  2019-10-25  246.729996  242.880005  243.160004  246.580002  18330500.0
#
#               Adj Close
#  Date
#  2014-10-28   97.944298
#  2014-10-29   98.494850
#  2014-10-30   98.164513
#  2014-10-31   99.100471
#  ...                ...
#  2019-10-22  239.960007
#  2019-10-23  243.179993
# ...

# %%
all_data.keys()
# Out:
# dict_keys(['AAPL', 'IBM', 'MSFT', 'GOOG'])

# %%
all_data["AAPL"]
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2014-10-28  106.739998  105.349998  105.400002  106.739998  48060900.0
# 2014-10-29  107.370003  106.360001  106.650002  107.339996  52687900.0
# 2014-10-30  107.349998  105.900002  106.959999  106.980003  40654800.0
# 2014-10-31  108.040001  107.209999  108.010002  108.000000  44639300.0
# ...                ...         ...         ...         ...         ...
# 2019-10-22  242.199997  239.619995  241.160004  239.960007  20573400.0
# 2019-10-23  243.240005  241.220001  242.100006  243.179993  18957200.0
# 2019-10-24  244.800003  241.809998  244.509995  243.580002  17318800.0
# 2019-10-25  246.729996  242.880005  243.160004  246.580002  18330500.0
#
#              Adj Close
# Date
# 2014-10-28   97.944298
# 2014-10-29   98.494850
# 2014-10-30   98.164513
# 2014-10-31   99.100471
# ...                ...
# 2019-10-22  239.960007
# 2019-10-23  243.179993
# 2019-10-24  243.580002
# 2019-10-25  246.580002
# ...

# %%
price = pd.DataFrame({ticker: data['Adj Close']
 for ticker, data in all_data.items()})
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2014-10-28   97.944298  132.482391   41.616329   547.397095
# 2014-10-29   98.494850  132.369003   41.732697   547.825928
# 2014-10-30   98.164513  133.089706   41.222458   548.803284
# 2014-10-31   99.100471  133.130219   42.028111   557.549255
# ...                ...         ...         ...          ...
# 2019-10-22  239.960007  133.960007  136.369995  1242.800049
# 2019-10-23  243.179993  134.380005  137.240005  1259.130005
# 2019-10-24  243.580002  134.070007  139.940002  1260.989990
# 2019-10-25  246.580002  135.440002  140.729996  1265.130005
#
# [1258 rows x 4 columns]

# %%
returns = price.pct_change()

# %%
volume = pd.DataFrame({ticker: data['Volume']
 for ticker, data in all_data.items()})
volume
# Out:
#                   AAPL        IBM        MSFT       GOOG
# Date
# 2014-10-28  48060900.0  7895300.0  29049800.0  1270900.0
# 2014-10-29  52687900.0  4739300.0  30276100.0  1770500.0
# 2014-10-30  40654800.0  3896000.0  30073900.0  1455600.0
# 2014-10-31  44639300.0  5818000.0  35849700.0  2035000.0
# ...                ...        ...         ...        ...
# 2019-10-22  20573400.0  4161600.0  27431000.0  1023800.0
# 2019-10-23  18957200.0  3610900.0  29844600.0   911500.0
# 2019-10-24  17318800.0  2598500.0  37029300.0  1028100.0
# 2019-10-25  18330500.0  2578000.0  25274600.0  1210100.0
#
# [1258 rows x 4 columns]

# %%
 returns.tail()
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2019-10-21  0.017343 -0.011261  0.007423  0.000530
# 2019-10-22 -0.002287  0.010409 -0.014881 -0.002688
# 2019-10-23  0.013419  0.003135  0.006380  0.013140
# 2019-10-24  0.001645 -0.002307  0.019674  0.001477
# 2019-10-25  0.012316  0.010219  0.005645  0.003283

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.48564523167596924

# %%
returns.corr() #AAPL ka AAPL k sth, IBM , MSFT , GOOG k sth corr
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.405330  0.572383  0.520488
# IBM   0.405330  1.000000  0.485645  0.412572
# MSFT  0.572383  0.485645  1.000000  0.655066
# GOOG  0.520488  0.412572  0.655066  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000246  0.000083  0.000133  0.000124
# IBM   0.000083  0.000170  0.000094  0.000082
# MSFT  0.000133  0.000094  0.000219  0.000147
# GOOG  0.000124  0.000082  0.000147  0.000230

# %%
returns.corrwith(returns.IBM) #IBM ko baqi sb ky sth
# Out:
# AAPL    0.405330
# IBM     1.000000
# MSFT    0.485645
# GOOG    0.412572
# dtype: float64

# %% [markdown]
# # UNIQUE VALUES , COUNTS, MEMBERSHIP

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts() #ordered count in descending order
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# a    3
# b    2
# c    3
# d    1
# dtype: int64

# %%
mask = obj.isin(['b', 'c'])
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool
